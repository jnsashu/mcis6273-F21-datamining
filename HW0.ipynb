# %% [markdown]
# # 1. Importing modules

# %%
import pandas as pd

# %% [markdown]
# # 2. Loading and exploring the data
#
# In this section the goals are to load the data into python and then to check its basic properties. This will include the dimension, column types and names, and missingness counts.

# %%
df = pd.read_csv('BKB_WaterQualityData_2020084.csv')
df.head() #head of the data sheet
# Out:
#   Site_Id Unit_Id  Read_Date  Salinity (ppt)  Dissolved Oxygen (mg/L)  \
# 0     Bay     NaN   1/3/1994             1.3                     11.7
# 1     Bay     NaN  1/31/1994             1.5                     12.0
# 2     Bay     NaN   2/7/1994             1.0                     10.5
# 3     Bay     NaN  2/23/1994             1.0                     10.1
# 4     Bay     NaN  2/28/1994             1.0                     12.6
#
#    pH (standard units)  Secchi Depth (m)  Water Depth (m)  Water Temp (?C)  \
# 0                  7.3              0.40             0.40              5.9
# 1                  7.4              0.20             0.35              3.0
# 2                  7.2              0.25             0.60              5.9
# 3                  7.4              0.35             0.50             10.0
# 4                  7.2              0.20             0.40              1.6
#
#    Air Temp-Celsius  Air Temp (?F) Time (24:00) Field_Tech DateVerified  \
# ...

# %%
df.tail() #Tail of the dataset
# Out:
#      Site_Id Unit_Id   Read_Date  Salinity (ppt)  Dissolved Oxygen (mg/L)  \
# 2366     Bay     NaN  10/11/2018             1.9                      5.0
# 2367     Bay     NaN  10/24/2018             0.0                      9.0
# 2368     Bay     NaN  10/28/2018             0.9                      2.9
# 2369     Bay     NaN   11/7/2018             1.7                      NaN
# 2370     Bay     NaN  12/11/2018             0.1                      NaN
#
#       pH (standard units)  Secchi Depth (m)  Water Depth (m)  Water Temp (?C)  \
# 2366                  7.0              4.00              1.2             25.0
# 2367                  7.0              0.30              0.6             18.0
# 2368                  7.0              0.40              0.9             13.0
# 2369                  7.0              0.45              0.9             20.0
# 2370                  7.0              0.10              0.1             10.0
#
# ...

# %%
df[df.Year.eq(2018)]
# Out:
#      Site_Id Unit_Id   Read_Date  Salinity (ppt)  Dissolved Oxygen (mg/L)  \
# 2208       A     NaN   1/16/2018             0.0                      NaN
# 2209       A     NaN   2/14/2018             0.0                      NaN
# 2210       A     NaN    3/7/2018             0.0                      NaN
# 2211       A     NaN   3/22/2018             0.0                      8.0
# 2213       A     NaN   4/17/2018             1.0                      NaN
# ...      ...     ...         ...             ...                      ...
# 2366     Bay     NaN  10/11/2018             1.9                      5.0
# 2367     Bay     NaN  10/24/2018             0.0                      9.0
# 2368     Bay     NaN  10/28/2018             0.9                      2.9
# 2369     Bay     NaN   11/7/2018             1.7                      NaN
# 2370     Bay     NaN  12/11/2018             0.1                      NaN
#
#       pH (standard units)  Secchi Depth (m)  Water Depth (m)  Water Temp (?C)  \
# ...

# %% [markdown]
# # 3. Query for years between 1999 & 2018

# %%
df1 = df.query('Year >= 1999 & Year <= 2018')

# %%
df1.head()
# Out:
#     Site_Id Unit_Id   Read_Date  Salinity (ppt)  Dissolved Oxygen (mg/L)  \
# 345       A     NaN   8/11/1999             3.0                     2.60
# 346       A     NaN   8/18/1999             3.0                     1.60
# 347       A     NaN    9/8/1999             1.8                     1.35
# 348       A     NaN  10/15/1999             0.1                     5.65
# 349       A     NaN  11/10/1999             0.0                     6.70
#
#      pH (standard units)  Secchi Depth (m)  Water Depth (m)  Water Temp (?C)  \
# 345                  7.7              0.60             0.60             26.0
# 346                  8.7               NaN              NaN             31.0
# 347                  8.2              0.40             1.00             28.0
# 348                  7.3              0.60             0.80             20.0
# 349                  7.6              0.65             0.95             18.0
#
# ...

# %%
df1.tail()
# Out:
#      Site_Id Unit_Id   Read_Date  Salinity (ppt)  Dissolved Oxygen (mg/L)  \
# 2366     Bay     NaN  10/11/2018             1.9                      5.0
# 2367     Bay     NaN  10/24/2018             0.0                      9.0
# 2368     Bay     NaN  10/28/2018             0.9                      2.9
# 2369     Bay     NaN   11/7/2018             1.7                      NaN
# 2370     Bay     NaN  12/11/2018             0.1                      NaN
#
#       pH (standard units)  Secchi Depth (m)  Water Depth (m)  Water Temp (?C)  \
# 2366                  7.0              4.00              1.2             25.0
# 2367                  7.0              0.30              0.6             18.0
# 2368                  7.0              0.40              0.9             13.0
# 2369                  7.0              0.45              0.9             20.0
# 2370                  7.0              0.10              0.1             10.0
#
# ...

# %% [markdown]
# # 4. Converting the slice to CSV file

# %%
df1.to_csv(r'C:\Users\ukaja\Documents\Ashwini_Telukuntla_Data_Mining\HW0\back_bay_1998-2018_clean.csv', index = False, header=True)

# %% [markdown]
# # 5. How many and what are the names of the columns in this dataset?

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1956 entries, 345 to 2370
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Site_Id                  1956 non-null   object
#  1   Unit_Id                  32 non-null     object
#  2   Read_Date                1956 non-null   object
#  3   Salinity (ppt)           1867 non-null   float64
#  4   Dissolved Oxygen (mg/L)  1150 non-null   float64
#  5   pH (standard units)      1872 non-null   float64
#  6   Secchi Depth (m)         1891 non-null   float64
#  7   Water Depth (m)          1890 non-null   float64
#  8   Water Temp (?C)          1842 non-null   float64
#  9   Air Temp-Celsius         46 non-null     float64
#  10  Air Temp (?F)            1904 non-null   float64
#  11  Time (24:00)             1905 non-null   object
#  12  Field_Tech               1956 non-null   object
# ...

# %%
df1.describe()
# Out:
#        Salinity (ppt)  Dissolved Oxygen (mg/L)  pH (standard units)  \
# count     1867.000000              1150.000000          1872.000000
# mean         0.410204                 5.867704             7.106490
# std          0.873802                 2.054290             0.799353
# min          0.000000                 0.000000             0.300000
# 25%          0.000000                 4.300000             6.500000
# 50%          0.000000                 5.900000             7.000000
# 75%          0.100000                 7.300000             7.500000
# max          8.000000                11.200000             9.900000
#
#        Secchi Depth (m)  Water Depth (m)  Water Temp (?C)  Air Temp-Celsius  \
# count       1891.000000      1890.000000      1842.000000         46.000000
# mean           0.558958         0.768701        18.096417         14.682609
# std            0.467386         0.615332         8.413927         13.818784
# ...

# %% [markdown]
# ## 6. What is the mean Dissolved Oxygen (mg/L) over the entire dataset?

# %% [markdown]
# Mean of Dissolved Oxygen (mg/L) is 5.867704 from df1.describe

# %% [markdown]
# ## 7. Which year were the highest number of AirTemp (C) data points collected?

# %% [markdown]
# From above we came to know that the highest number of AirTemp(C) is 33 from df1.describe

# %%
df1.columns = [c.replace(' ', '_') for c in df1.columns]

# %%
df1.columns = [c.replace('(', '') for c in df1.columns]

# %%
df1.columns = [c.replace(')', '') for c in df1.columns]

# %%
df1.columns = [c.replace('/', '') for c in df1.columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1956 entries, 345 to 2370
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Site_Id                1956 non-null   object
#  1   Unit_Id                32 non-null     object
#  2   Read_Date              1956 non-null   object
#  3   Salinity_ppt           1867 non-null   float64
#  4   Dissolved_Oxygen_mg/L  1150 non-null   float64
#  5   pH_standard_units      1872 non-null   float64
#  6   Secchi_Depth_m         1891 non-null   float64
#  7   Water_Depth_m          1890 non-null   float64
#  8   Water_Temp_?C          1842 non-null   float64
#  9   Air_Temp-Celsius       46 non-null     float64
#  10  Air_Temp_?F            1904 non-null   float64
#  11  Time_24:00             1905 non-null   object
#  12  Field_Tech             1956 non-null   object
#  13  DateVerified           386 non-null    object
# ...

# %%
df1.query('AirTemp_C == 33')
# Out:
#     Site_Id Unit_Id  Read_Date  Salinity_ppt  Dissolved_Oxygen_mg/L  \
# 346       A     NaN  8/18/1999           3.0                    1.6
#
#      pH_standard_units  Secchi_Depth_m  Water_Depth_m  Water_Temp_?C  \
# 346                8.7             NaN            NaN           31.0
#
#      Air_Temp-Celsius  Air_Temp_?F Time_24:00    Field_Tech DateVerified  \
# 346               NaN         91.4       9:36  Not Recorded          NaN
#
#     WhoVerified  AirTemp_C  Year
# 346         NaN       33.0  1999

# %% [markdown]
# 1999 is the year highest number of AirTemp (C) data points collected

# %% [markdown]
# ## 8. Which year were the least number of AirTemp (C) data points collected?

# %% [markdown]
# From the above we know the least number of AirTemp (C) data points collected is -17.777778 from df1.describe

# %%
df1.query('AirTemp_C <= -17')
# Out:
#      Site_Id Unit_Id   Read_Date  Salinity_ppt  Dissolved_Oxygen_mg/L  \
# 348        A     NaN  10/15/1999           0.1                   5.65
# 349        A     NaN  11/10/1999           0.0                   6.70
# 354        B     NaN    9/8/1999           0.9                   3.60
# 355        B     NaN  10/15/1999           1.0                   4.70
# 357        B     NaN  11/10/1999           1.0                   6.30
# 362        C     NaN    9/8/1999           1.0                   2.40
# 364        C     NaN  10/15/1999           0.1                   5.50
# 366        C     NaN  11/10/1999           0.2                  10.00
# 371        D     NaN    9/8/1999           0.0                   1.50
# 372        D     NaN   9/22/1999           0.0                   1.90
# 373        D     NaN  10/15/1999           0.0                   3.25
# 380      Bay     NaN   1/23/1999           1.1                  11.20
# ...

# %% [markdown]
# 1999
# 2000
# 2001
# 2002
# 2004
# 2005
# 2006
# 2008
# 2010
# 2017
# Above are the years least number of AirTemp (C) data points collected which is -17.777778

# %% [markdown]
# ## 9. Which sampling location has the highest mean ppt? What is the equivalent ppm?

# %%
df1.query('Salinity_ppt == 0.4')
# Out:
#     Site_Id Unit_Id   Read_Date  Salinity_ppt  Dissolved_Oxygen_mg/L  \
# 374       D     NaN  10/27/1999           0.4                    3.4
#
#      pH_standard_units  Secchi_Depth_m  Water_Depth_m  Water_Temp_?C  \
# 374                7.4            0.95           1.35           42.5
#
#      Air_Temp-Celsius  Air_Temp_?F Time_24:00    Field_Tech DateVerified  \
# 374               NaN         72.0       0:00  Not Recorded          NaN
#
#     WhoVerified  AirTemp_C  Year
# 374         NaN  22.222222  1999

# %% [markdown]
# Based on the df1.describe() mean of ppt is 0.4. Location D has the highest mean ppt and equivalent ppm is 3.4

# %% [markdown]
# ## 10. When looking at the mean ppt, which location would you infer is furthest from the influence of ocean water inflows? (Assume that higher salinity correlates to closer proximity to the ocean.)

# %%
df1.describe()
# Out:
#        Salinity_ppt  Dissolved_Oxygen_mg/L  pH_standard_units  Secchi_Depth_m  \
# count   1867.000000            1150.000000        1872.000000     1891.000000
# mean       0.410204               5.867704           7.106490        0.558958
# std        0.873802               2.054290           0.799353        0.467386
# min        0.000000               0.000000           0.300000        0.000000
# 25%        0.000000               4.300000           6.500000        0.300000
# 50%        0.000000               5.900000           7.000000        0.500000
# 75%        0.100000               7.300000           7.500000        0.700000
# max        8.000000              11.200000           9.900000        7.400000
#
#        Water_Depth_m  Water_Temp_?C  Air_Temp-Celsius  Air_Temp_?F  \
# count    1890.000000    1842.000000         46.000000  1904.000000
# mean        0.768701      18.096417         14.682609    61.604748
# ...

# %%
df1.query('Salinity_ppt == 0')
# Out:
#      Site_Id Unit_Id   Read_Date  Salinity_ppt  Dissolved_Oxygen_mgL  \
# 349        A     NaN  11/10/1999           0.0                  6.70
# 365        C     NaN  10/27/1999           0.0                  3.70
# 371        D     NaN    9/8/1999           0.0                  1.50
# 372        D     NaN   9/22/1999           0.0                  1.90
# 373        D     NaN  10/15/1999           0.0                  3.25
# ...      ...     ...         ...           ...                   ...
# 2362       D     NaN  10/24/2018           0.0                   NaN
# 2363       D     NaN  10/28/2018           0.0                   NaN
# 2364       D     NaN   11/7/2018           0.0                  6.90
# 2365       D     NaN  12/11/2018           0.0                   NaN
# 2367     Bay     NaN  10/24/2018           0.0                  9.00
#
#       pH_standard_units  Secchi_Depth_m  Water_Depth_m  Water_Temp_?C  \
# ...

# %% [markdown]
# Many locations has Salinity ppt with 0 value Site id's are A,C,D & Bay

# %% [markdown]
# ## 11. Dig a little deeper into #2, and write why there may be some uncertainty in your answer? (hint: certainty is improved by consistency in data)

# %%
df1.query('Salinity_ppt == 0 & Dissolved_Oxygen_mgL == 0')
# Out:
#      Site_Id Unit_Id  Read_Date  Salinity_ppt  Dissolved_Oxygen_mgL  \
# 1937       A   01CSV  6/10/2014           0.0                   0.0
# 1938       B   01CSV  6/10/2014           0.0                   0.0
#
#       pH_standard_units  Secchi_Depth_m  Water_Depth_m  Water_Temp_?C  \
# 1937                7.0             0.5            0.7           27.0
# 1938                8.0             0.3            0.3           27.0
#
#       Air_Temp-Celsius  Air_Temp_?F Time_24:00 Field_Tech DateVerified  \
# 1937              23.0         74.0      11:00    Sue Poe    6/23/2014
# 1938              74.0         23.0      10:50    Sue Poe    6/23/2014
#
#          WhoVerified  AirTemp_C  Year
# 1937  Trenton Miller  23.333333  2014
# 1938  Trenton Miller  -5.000000  2014

# %% [markdown]
# Solubility of dissolved oxygen also decreases as salinity increases, based on this the dissolved oxygen with minimum is 0 and salinity 0 has Site ID with A & B

# %% [markdown]
# ## 12. Use the data to determine the correlation between Salinity (ppt) and pH (standard units). Use the DataFrame.corr(). You just need to report the correlation value.

# %%
df1.corr()
# Out:
#                       Salinity_ppt  Dissolved_Oxygen_mgL  pH_standard_units  \
# Salinity_ppt              1.000000             -0.096862           0.271262
# Dissolved_Oxygen_mgL     -0.096862              1.000000          -0.069449
# pH_standard_units         0.271262             -0.069449           1.000000
# Secchi_Depth_m           -0.077506              0.096643          -0.130557
# Water_Depth_m            -0.119635              0.054607          -0.182553
# Water_Temp_?C             0.008669             -0.564673           0.174527
# Air_Temp-Celsius               NaN             -0.512446           0.505689
# Air_Temp_?F               0.066299             -0.560187           0.191483
# AirTemp_C                 0.039016             -0.411543           0.116325
# Year                     -0.416750              0.108474          -0.360782
#
#                       Secchi_Depth_m  Water_Depth_m  Water_Temp_?C  \
# ...

# %% [markdown]
# Correlation between Salinity & pH is 0.271262
